# %%
import pandas as pd
df = pd.read_parquet("../00003-51-f1b5a6f3-3f6b-466c-9f77-a283dd6f8ea9-0-00001.parquet")

# %%
df
# Out:
#            artifact_set_id                       created_at  \
# 0  dsl_001_20260217_231736 2026-02-17 23:18:02.423337+00:00
#
#          raw_snapshot                       processed_table_name  \
# 0  130093729659772017  iceberg.processed.dsl_001_20260217_231736
#
#        dsl_name     pipeline_hash               train_start  \
# 0  dsl_001.yaml  551b161cba801dee 2026-01-01 00:30:00+00:00
#
#                   train_end                 val_start  \
# 0 2026-01-01 13:00:00+00:00 2026-01-01 13:00:00+00:00
#
#                     val_end                test_start  \
# 0 2026-01-02 05:40:00+00:00 2026-01-02 07:00:00+00:00
#
#                    test_end
# 0 2026-01-03 03:50:00+00:00
