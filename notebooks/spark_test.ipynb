# %%
import pandas as pd
df = pd.read_parquet("out/2026_02_01_002.parquet")

# %%
df['timestamp'].min(), df['timestamp'].max()
# Out:
# (Timestamp('2026-02-01 03:00:11'), Timestamp('2026-02-01 19:39:45'))
