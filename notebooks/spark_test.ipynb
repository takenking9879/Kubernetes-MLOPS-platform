# %%
import pandas as pd
df = pd.read_parquet("../00003-50-7445f650-46aa-4d84-b11f-22f788df38d4-0-00001.parquet")

# %%
df.head(3)
# Out:
#   artifact_set_id                       created_at         raw_snapshot  \
# 0          235537 2026-03-02 23:58:58.653888+00:00  8506354634879513289
#
#                        processed_table_name                  dsl_name  \
# 0  iceberg.processed.network_traffic_235537  v1__network_traffic.yaml
#
#       pipeline_hash raw_dataset_name               train_start  \
# 0  9ccc14a21296bf04  network_traffic 2026-01-01 00:30:00+00:00
#
#                   train_end                 val_start  \
# 0 2026-01-01 13:00:00+00:00 2026-01-01 13:00:00+00:00
#
#                     val_end                test_start  \
# 0 2026-01-02 05:40:00+00:00 2026-01-02 07:00:00+00:00
#
#                    test_end
# 0 2026-01-03 03:50:00+00:00
