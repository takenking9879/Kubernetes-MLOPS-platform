# %%
import pandas as pd
df = pd.read_parquet("../00003-50-cc4e300f-8b79-4c23-a68c-32e84b54c66c-0-00001.parquet")

# %%
df.head(3)
# Out:
#    artifact_set_id                       created_at         raw_snapshot  \
# 0  20260227_213444 2026-02-27 21:36:09.442688+00:00  8506354634879513289
#
#                                 processed_table_name  \
# 0  iceberg.processed.network_traffic_20260227_213444
#
#                    dsl_name     pipeline_hash raw_dataset_name  \
# 0  v1__network_traffic.yaml  9ccc14a21296bf04  network_traffic
#
#                 train_start                 train_end  \
# 0 2026-01-01 00:30:00+00:00 2026-01-01 13:00:00+00:00
#
#                   val_start                   val_end  \
# 0 2026-01-01 13:00:00+00:00 2026-01-02 05:40:00+00:00
#
#                  test_start                  test_end
# 0 2026-01-02 07:00:00+00:00 2026-01-03 03:50:00+00:00
