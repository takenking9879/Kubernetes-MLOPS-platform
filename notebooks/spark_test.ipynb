# %%
import pandas as pd
df = pd.read_parquet("out/2026_02_01_002.parquet")

# %%
df.head(1)
# Out:
#    src_port  dst_port protocol  packet_count conn_state  bytes_transferred  \
# 0      9467     10155      TCP           255        EST      229446.849561
#
#             timestamp  attack
# 0 2026-02-01 03:00:11       3
